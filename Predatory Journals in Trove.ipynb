# %% [markdown]
# ## Finding predatory journals in Trove
# #### Create by Ziting Zhang
#
#     This notebook is aiming to retrieve all journal articles in Trove and find out which ones are on the predatory list,
#     which is Beall's list in this notebook.
#
#     As for Tim Sherratt has done some related works (https://glam-workbench.github.io/trove-journals/) on this field , it
#     makes me easier to find references for my notebook.
#
#     In Tim Sherratt's work, he retrieved the journals that have digital resources online, but what I need to find
#     is all journal articles, so there should be a large amount of resources that need to be retrieved out.
#
#     Now let's start with importing the required libraries that the first part of the notebook needed.

# %% [markdown]
# ## Part 1

# %% [markdown]
# ## Libraries
#     All libraries to be used in this part.

# %%
#for HTTP request
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# show a smart progress meter
from tqdm import tqdm_notebook
# display tools in IPython
from IPython.display import display, FileLink
# provide dataframe for data analysis
import pandas as pd
# json page API
import json

# %% [markdown]
# ## Set API key and request session
#     Now, we have all the supported libraries for the first part, so we can start with using the Trove API.
#
#     For using the Trove API, the first thing you need to do is get your own Trove API key to make use of
#     Trove API. The following key is mine own API key and you need to change it to your own one after apply
#     for the key.
#
#     Do not feel worry about getting the API key, just follow these steps:
#     1. Go to the Trove official website (https://trove.nla.gov.au/)
#     2. Click 'API' at the bottom of the page.
#     3. Then you can follow the instruction called 'How do I get an API key?' provided by Trove to get your API key.

# %%
api_key = '9aqiim9kqb98hqvt'  #change to your own API key

# %% [markdown]
#     The session object is mainly used to persist certain parameters, like cookies, across different HTTP requests.
#     A session object may use a single TCP connection for handling multiple network requests and responses, which
#     results in performance improvement.
#     Set retry times to avoid temperory connection issues.

# %%
s = requests.Session()
retries = Retry(total=5, backoff_factor=1, status_forcelist=[ 502, 503, 504 ])
s.mount('https://', HTTPAdapter(max_retries=retries))
s.mount('http://', HTTPAdapter(max_retries=retries))

# %% [markdown]
# ## Set configurations
#
#     It's the time for modifying the search query used for Trove API!
#
#     Now let's think about what things we need to retrieve from the Trove database. All the journal articles in Trove.
#     So we need to know where are these resources stored in the database. In Trove, there are several zones for storing
#     different kind of resources. The one contains journal articles is called 'Journals, articles and datasets'.

# %%
# prefix of the search query
api_search_url = 'https://api.trove.nla.gov.au/v2/result'
params = {
    'key': api_key,                 # key -- API key
    'zone': 'article',              # zone -- Trove zones. article refers to zone "Journals, articles and data sets"
    'q': ' ',                       # q -- query
    'bulkHarvest': 'true',          # bulkHarvest -- set the order consistantly
    'n': 100,                       # n -- number in each page. Maximun 100 per page.
    'encoding': 'json',             # encoding -- can be json or xml
    'l-format': 'Periodical',       # l-format -- set "Periodical" to avoid articles not in journal.
    'l-availability': 'y',          # l-availability -- available online
    'l-australia': 'y',             # l-australia -- set yes to ensure the resources to be found is from Australia
    'l-language': 'English',        # l-language -- set 'English' to retrieve english content resources
    's': '*'                        # s -- use for turning the page
}
these_params = params.copy()

# %% [markdown]
# ## Start harvesting
#
#     Using the set configurations to find the results in Trove
#     The specific frame of finding works refers to the results returned by Trove
#     The name and troveURL will be stored in the dataframe.

# %%
def zone_finder():

    start = '*'
    
    names = []
    troveURL = []
    contributor = []
    while start:
        these_params['s'] = start #Set s to be the first page and then be the value of 'nextStart'.
        response = s.get('https://api.trove.nla.gov.au/v2/result', params=these_params) 
        
        #if you don't want to see the reponse json page, please comment the following line
        #results url will be showed below. Click to see the detailed information.
        print(response.url)
        
        #store the reponse json page in data
        data = response.json()
        
        try:
            #refer to the frame returned by Trove
            start = data['response']['zone'][0]['records']['nextStart']
        except KeyError:
            #If error stopped searching
            start = None
        # Loop through the works in data
        for work in data['response']['zone'][0]['records']['work']:
            # Add the article information into names and troveURL
            names.append(work['title'])
            troveURL.append(work['troveUrl'])
    # Return the names and url to a dataframe
    return pd.DataFrame({'names': names, 'TroveURL': troveURL})

#call the method zone_finder()
result = zone_finder()
# Out:
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=%2A
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDA1MjM0MA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDA5NTg3NQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDE0MDM4OA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDE2Mzk3NA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDIwNTA1Ng%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDIyNjc5MA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDIzNTExMA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDI2NTAxMg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDI3NTM3Nw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDI4Mjg3Mg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDMxNjgzMA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDMyMTczNg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDMyNzI1NQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDM3NzcxMg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDQwMTUxOQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDQwOTQ0MQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDQyODI1Nw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDQ1NTgzOA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDQ1OTk1NA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDUxNjM2Ng%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDUyNDYzNA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDU1OTM5MA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDU4NTA2OQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDYxOTY1MQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDYzOTQzOA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDcwMjkzMQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDc0OTMwOA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDc3NzA4Ng%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDgxNTU0Mw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg1MzY3Mw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg2ODM2Mg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg3NjQwOA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg3NzE0Nw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg3ODA3OQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg3ODg0OA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg4MDAwMw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg4MTU3MA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg4MjgzNQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg4NDAyMg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg4NTU5NA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg4NzM1Mg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg4OTEyMw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg5MTQyMQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg5MzM2OQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg5NDk1Ng%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg5NjQzMg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg5ODA2Ng%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDg5OTY3NQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDkwMTgyMw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDkwNDI4Mg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDkwNjQ0Mg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDkwODY4Mg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDkxMDkyOA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDkxMjU4Mg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDkxNDY3NQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDkxNzAzOA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDkxOTgzNA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDkyMjY1Nw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDkyNDYyNA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDkyNzA2MQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDkzNTAxNw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMDk3NTQyNw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTAwNTIxOQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTAwOTA1MQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTA0NzcxMg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTEwMDEzMw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTE0OTA1NA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTE3MDQ1OA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTIwMjYyNg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTIyNDk3Ng%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTIyODA3OA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTIzMTM5NQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTIzNTI2Mg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTIzODg5MA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI0MjgwNg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI0NTM4Ng%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI0NzkwMQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI1MTM3Nw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI1Njg3MQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI2MDc3MQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI2NDgxOQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI2NzUxNg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI2ODk3OA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI3MDYxNQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI3Mzg5NA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI3NzExMg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI4MDEyNA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI4NDE0Nw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI4NjAxNg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI4OTI2Ng%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI5MzM3NA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTI5NzYxNw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTMwMDM4MA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTMwNDA4Mg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTMwNzkyMA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTMxMTU1Nw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTMxNjEyMA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTM0OTMzNw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTM1MjY5OA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTM1NTA2NA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTM2MTExNg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTM2Njk2NA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTM3Mjc1Mw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTM3ODM0OA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTM4Mzk5OQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTM4OTAxMw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTM5MjY4OA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTM5NzU5OA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTQxNjMyMQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTQyMDM5NQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTQyNDQzNA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTQ0NTk0OA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTQ2NzUyOQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTUwMjQ1Mg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTUzMTI1Mg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTYwOTAzNA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTYyOTk4Mw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTY2MTcxMA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTY5MTk5NQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTcxNjgxMQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTc1ODMyOQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTc5NTcyMw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTgzNjcwNA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTkwOTcxNA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMTk5MjAzNw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMjA0NjM5OA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMjEyMDc0Mw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMjIxMTcyMw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMjMwODgzMA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMjM4NTI1Mw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMjQ4ODI2Mw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMjU5MTQ4OQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMjY2OTQxNw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMjcyNTU2NQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMjc4ODQyMw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMjk0MDU3MA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMzAwNTg1Mg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMzA4NjM4Ng%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMzE1MDg0MA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMzE4ODk4Mg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMzI2NzM3Nw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMzM5ODE2OQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMzQ1MjA2OQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMzY1MzYxOA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMzg1MTU5NA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxMzk5MjU4Mg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNDAyNjcwMQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNDEwMDk4Nw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNDEwNzk1OA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNDQ1NzY2MQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNDYzOTU1Nw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNDY5NTc0Ng%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNDkzNDI5NA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNDk5MTk4OQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTEyNDMxMDU%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTEyNDM1MzU%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTEzOTkyMDk%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTE1ODY2MDg%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTIxNDEyNTA%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTIxNDE1NTQ%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTIxNDE3MTM%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTIzMzY1Mjc%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTI3Mzg4OTk%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTMzOTczMjM%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTM1NzM3ODQ%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTM4NDAxMDI%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTQxMjI2OTE%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTQ3MTcyODI%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTQ3MTc4NTk%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNTQ5NzIzMQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTUwMDM5OTY%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTU2ODY3NDY%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTU5NjMwODk%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTYyMzQ2NTE%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTY1NDQ3Mzg%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNTY3NDA4OA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTY5MjUyMzk%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTcxMDY3NDA%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTc1NjkzNzU%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTc5NDQ5NTA%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTgyNzQ2MzQ%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTg1MDIyNzE%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTg1OTk1MjA%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTg1OTk2MjA%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTg3MTA2NzI%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTkwMzIzMzM%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTkxNDIwMDQ%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTkxNDI4NTc%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTkxNDM5Mjk%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTkxNDUxMjc%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTkyMzI2MTY%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTk0MTEzMDQ%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNTk1NTI2MA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNTk2ODI5Mw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNTk4NTQ0ODQ%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNTk5MTMxNQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNTk5NzA5Nw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNjAwMzAzNg%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNjAwODkzNA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNjAxMzA5NQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjAzMDgzNjM%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjAzMDg0NjQ%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNjA0ODI4Mw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjA3NTY3NjA%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjExNzYzMTY%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNjEyNDY3OA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjE2NzYwMzk%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjE3NDg3MTI%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNjE5MzAzOA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNjE5NTEwNA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNjE5NzUzNQ%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNjIwODQwNA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNjIxNzQzMA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjIzMTc1MzM%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjI2MTc2OTU%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3UxNjI2NzAzMA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjI4MTM0MDM%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjI5NDg4OTE%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjI5NDkxMzQ%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjI5NTAyOTc%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjI5NzYzMDI%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjI5NzY4MjI%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjI5Nzc2MjU%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjI5Nzc5MjI%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjI5Nzg1ODM%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjI5NzkwOTk%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoErc3UxNjI5Nzk0OTU%3D
# ...
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U3NjY1OTA1
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U3NjcxMzk2
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U3NzA5MTE3
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U3NzEwNTI3
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U3NzExNjQw
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U3NzE4MDMw
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U3NzU1ODc1
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U3NzkzNzg3
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U3ODQxMDY5
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U3ODY0Mjc0
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U3OTExNTg4
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U3OTU2NzM4
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U3OTk3NjIw
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MDA4MzU4
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MDE4MjM2
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MDY1MjEx
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MDkwMDcw
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3U4MDkzMDYyMw%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MDk5MDAy
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEqc3U4MTExODE2OA%3D%3D
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MTE3MzU5
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MTcyMTc0
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MTc0ODk3
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MjI5MTk0
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MjY4MDAw
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MzEwNzY0
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MzEzNDI4
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MzE1NDQ5
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MzE5NTI5
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MzIxNTA2
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MzMzODY0
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MzQxMDE1
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MzU0NzYz
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4MzgwMTU1
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4Mzg0OTg4
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4NDA1NjEy
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4NDI1Mzk1
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4NDQ3OTAw
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4NDkzMTA3
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4NTAzMTA5
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4NTI5ODM2
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4NTM3MDUx
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4NTU1NjI1
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4NTg0OTkz
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4NjAzNzQ5
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4NjI3MDgz
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4NjU1NjE2
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4Njk0NjI1
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4NzI0NDk1
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4NzUyODMy
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4Nzc5MjMz
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4ODUxNjk4
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4OTI1ODYz
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4OTQzNjIz
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U4OTg4MjQy
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5MDIyODY2
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5MDI2OTc4
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5MDY2NTUw
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5MTEzODMx
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5MTg5Mjc5
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5MjYwMjUz
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5Mjc4ODU0
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5Mjk4NTc0
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5MzE1MDIx
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5NDY2Nzcx
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5NDk3NDU1
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5NTU0ODcz
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5NTcxMzYy
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5NjE1NTAw
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5NjUxNTA3
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5NjcwNTM3
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5NzA1ODQ1
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5NzMzNDg1
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5Nzg2MjI1
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5ODEyNjY3
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5ODY0NTA0
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5OTE4MTE4
# https://api.trove.nla.gov.au/v2/result?key=9aqiim9kqb98hqvt&zone=article&q=+&bulkHarvest=true&n=100&encoding=json&l-format=Periodical&l-availability=y&l-australia=y&l-language=English&s=AoEpc3U5OTc0NTAz

# %%
df_url = pd.read_csv("./predatory_journals_with_url.csv", sep = ',' ,header = None)
pd.set_option('max_colwidth',100)
df_url.head()
# Out:
#                                                                        0  \
# 0                                                                  names
# 1      Reports / North Atlantic Assembly, Defence and Security Committee
# 2  Reports / North Atlantic Assembly, Scientific and Technical Committee
# 3                 Reports / North Atlantic Assembly, Political Committee
# 4                                        Western fisheries (Perth, W.A.)
#
#                                         1
# 0                                TroveURL
# 1  https://trove.nla.gov.au/work/10002103
# 2  https://trove.nla.gov.au/work/10002106
# 3  https://trove.nla.gov.au/work/10002110
# 4  https://trove.nla.gov.au/work/10002212

# %% [markdown]
# ## Save dataframe into CSV file
#     Save the data into CSV file with two columns which refer to the title and the Trove url.
#     Once the data is saved, we do not need to rerun the previous steps because it takes pretty much time.
#     We can simply use the CSV file for further uses.

# %%
#save to dataframe
df = pd.DataFrame(result)
#save to csv file
df.to_csv('Trove_journals_with_url.csv', index=False)

# %% [markdown]
#     Now, we get 301847 items from Trove which is pretty large number of journal articles.
#     This number can be varied because the Trove database is updating over time.

# %% [markdown]
# # Part2
# ## Comparison
#     Compare the data extract in the previous step with Beall's predatory list
#     Using fuzzy function in this part to avoid the same journal can not be found which from different resources.
#     Fuzzy ratio set to 90 out of 100 to avoid to find large amount of journals.
#
# ## Import libraries
#     First we need to install the modules we do not have, just run the following cell to make it completed!

# %%
# !pip install fuzzywuzzy
# !pip install xlrd
# Out:
# Requirement already satisfied: fuzzywuzzy in e:\project\lib\site-packages (0.17.0)
# Requirement already satisfied: xlrd in e:\project\lib\site-packages (1.2.0)

# %% [markdown]
#     Then import the required libraries for part 2

# %%
#for calculations in Python
import numpy as np
#provide dataframe
import pandas as pd
#fuzzy function
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %% [markdown]
# ## Read journals in predatory list from CSV file and transfer to list
#     In this part, the predatory list we use is the Beall's list. As Beall's list is not difficult to find on the website,
#     I copy the names of the journals in the list to an CSV file from https://beallslist.weebly.com/.
#
#     Then, loading the CSV file into the dataframe for further uses.

# %%
#load into dataframe
df2 = pd.read_csv("./list.csv", sep = ',' ,header = None)
#save the names into a list
list2 = df2[0].tolist()

# %% [markdown]
# ## Compare extract data with predatory list
#     In this section, the names from Trove and Beall's list will be compared, and the same ones will be regarded as
#     the results we found.
#
#     In this part, the data from Trove and Beall’s list need to do the comparison. But in this process, I found that
#     some names are slightly different. For example, “Scientific journals international” from Trove and “Scientific
#     Journals International” are the same, but their names have few differences. You will see this example in the
#     results below. These problems can cause the same journal to fail to match among two datasets. In order to solve
#     this problem, I added a fuzzy function in the process of comparison. The fuzzy function can calculate the
#     similarity between two strings.
#
#     In this situation, I set the similarity of two names to 90% to get similar names and ensure that there would not be too many errors.
#     As there are 30 journals can be retrieved out, I can manually check if the two journals are the same in different
#     datasets by using the links on Beall’s list’s website.
#
#     This should be a long process, if you are working on a hign performance server it will become faster.

# %%
#read journals from csv file
df_article = pd.read_csv("./Trove_journals_with_url.csv", sep = ',' ,header = None)
#transfer to list
list_art = df_article[0].tolist()
count_art = 0
count = 0
list_trove = []
list_pre = []
#find matchings
for p in list2: #name in predatory list
    for l in list_art: #name in Trove
        #use fuzzy function
        score = fuzz.ratio(l.lower(),p.lower()) #strings to lowercase
        if score > 90 :
            count_art = count_art + 1 #count the number
            list_trove.append(l) #add into list
            list_pre.append(p)
            break

# %% [markdown]
#     Load the journal articles with the Trove url into the dataframe

# %% [markdown]
# ## Count the number of journals found
#     Here are the total number of items found by comparison

# %%
count_art
# Out:
# 30

# %% [markdown]
# ## List them all and manually check
#     First let's have a look of the names found from Trove

# %%
list_trove
# Out:
# ['Oasis',
#  'Dance research journal',
#  'American research journal',
#  'RSC journals',
#  'ARN journal',
#  'AIDScience',
#  'Computer Science Journal',
#  'Esk journal',
#  'European journal of educational studies',
#  'International journal on computer science and engineering',
#  'International CLIL research journal',
#  'Air international',
#  'Medical science',
#  'ET journal',
#  'Newpubli',
#  'Open Journal Systems',
#  'RIRDC publications',
#  'APS Journals',
#  'Revista acadêmica',
#  'JSAP international',
#  'ScienceAlert',
#  'Science and technology publishing',
#  'Scientific journals international',
#  'Scitech',
#  'Scitech',
#  'RSCAS Publications',
#  'CTI journal',
#  'ULK scientific journal',
#  'HVS international journal',
#  'World scholar']

# %% [markdown]
#     Then let's found the url for these journal articles.
#
#     Here the dictionary is used for finding the paired url for journal articles.
#     A dictionary is a collection which is unordered, changeable and indexed. In Python, dictionaries are written
#     with curly brackets, and they have keys and values.
#     We use names as the keys to find its values, which are urls.

# %%
dict_trove = df_url.set_index(0).T.to_dict('list')
urls = []
for title in list_trove:
    urls.append(dict_trove.get(title))
# Out:
# E:\project\lib\site-packages\ipykernel_launcher.py:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
#     Here is the results of the journal articles found with their urls.

# %%
trove = pd.DataFrame({'names': list_trove, 'TroveURL': urls})
trove
# Out:
#                                                 names  \
# 0                                               Oasis
# 1                              Dance research journal
# 2                           American research journal
# 3                                        RSC journals
# 4                                         ARN journal
# 5                                          AIDScience
# 6                            Computer Science Journal
# 7                                         Esk journal
# 8             European journal of educational studies
# 9   International journal on computer science and ...
# 10                International CLIL research journal
# 11                                  Air international
# 12                                    Medical science
# 13                                         ET journal
# 14                                           Newpubli
# 15                               Open Journal Systems
# 16                                 RIRDC publications
# 17                                       APS Journals
# 18                                 Revista acadêmica
# 19                                 JSAP international
# 20                                       ScienceAlert
# 21                  Science and technology publishing
# 22                  Scientific journals international
# 23                                            Scitech
# 24                                            Scitech
# 25                                 RSCAS Publications
# 26                                        CTI journal
# 27                             ULK scientific journal
# 28                          HVS international journal
# 29                                      World scholar
#
#                                      TroveURL
# 0    [https://trove.nla.gov.au/work/37193230]
# 1    [https://trove.nla.gov.au/work/38309383]
# 2   [https://trove.nla.gov.au/work/189974372]
# 3    [https://trove.nla.gov.au/work/28410399]
# 4    [https://trove.nla.gov.au/work/11351373]
# 5    [https://trove.nla.gov.au/work/28646447]
# 6   [https://trove.nla.gov.au/work/165736143]
# 7    [https://trove.nla.gov.au/work/20852549]
# 8    [https://trove.nla.gov.au/work/35153346]
# 9   [https://trove.nla.gov.au/work/151780769]
# 10  [https://trove.nla.gov.au/work/157653308]
# 11   [https://trove.nla.gov.au/work/11456146]
# 12  [https://trove.nla.gov.au/work/192357204]
# 13   [https://trove.nla.gov.au/work/31352640]
# 14  [https://trove.nla.gov.au/work/215480524]
# 15   [https://trove.nla.gov.au/work/37784914]
# 16   [https://trove.nla.gov.au/work/35051004]
# 17  [https://trove.nla.gov.au/work/228912896]
# 18  [https://trove.nla.gov.au/work/187074215]
# 19    [https://trove.nla.gov.au/work/7502056]
# 20   [https://trove.nla.gov.au/work/34480289]
# 21  [https://trove.nla.gov.au/work/235255163]
# 22   [https://trove.nla.gov.au/work/11673096]
# 23   [https://trove.nla.gov.au/work/23438817]
# 24   [https://trove.nla.gov.au/work/23438817]
# 25  [https://trove.nla.gov.au/work/154717273]
# 26   [https://trove.nla.gov.au/work/16209918]
# 27  [https://trove.nla.gov.au/work/227472101]
# 28   [https://trove.nla.gov.au/work/19470015]
# 29   [https://trove.nla.gov.au/work/20176054]

# %% [markdown]
#     Then let's have a look of the ones found in Beall's list.
#
#     Are they the same ones?

# %%
list_pre
# Out:
# ['OASIS)',
#  'Advanced Research Journals',
#  'American Research Journals',
#  'ARC Journals',
#  'ARPN Journals',
#  'Avid Science',
#  'Computer Science Journals',
#  'Eko Journal',
#  'European Journals of Education Studies',
#  'International Conference on Computer Science and Engineering',
#  'International Skill Research Journals',
#  'IORE International',
#  'Medical science',
#  'Net Journals',
#  'Newpubli',
#  'Open Journal Systems',
#  'ORIC Publications',
#  'PBS Journals',
#  'Revistas Academicas',
#  'SAVAP International',
#  'Science Alert',
#  'Science and Technology Publishing',
#  'Scientific Journals International',
#  'SCITECH',
#  'Scitechz',
#  'SS Publications',
#  'TI Journals',
#  'USN Scientific Journal',
#  'VSRD International Journals',
#  'World Scholars']

# %% [markdown]
#     Let's put them into one table to have a clear look

# %%
comparison = pd.DataFrame({'journals from Trove': list_trove, 'journals from Bealls list': list_pre})
comparison
# Out:
#                                   journals from Trove  \
# 0                                               Oasis
# 1                              Dance research journal
# 2                           American research journal
# 3                                        RSC journals
# 4                                         ARN journal
# 5                                          AIDScience
# 6                            Computer Science Journal
# 7                                         Esk journal
# 8             European journal of educational studies
# 9   International journal on computer science and ...
# 10                International CLIL research journal
# 11                                  Air international
# 12                                    Medical science
# 13                                         ET journal
# 14                                           Newpubli
# 15                               Open Journal Systems
# 16                                 RIRDC publications
# 17                                       APS Journals
# 18                                 Revista acadêmica
# 19                                 JSAP international
# 20                                       ScienceAlert
# 21                  Science and technology publishing
# 22                  Scientific journals international
# 23                                            Scitech
# 24                                            Scitech
# 25                                 RSCAS Publications
# 26                                        CTI journal
# 27                             ULK scientific journal
# 28                          HVS international journal
# 29                                      World scholar
#
#                             journals from Bealls list
# 0                                              OASIS)
# 1                          Advanced Research Journals
# 2                          American Research Journals
# 3                                        ARC Journals
# 4                                       ARPN Journals
# 5                                        Avid Science
# 6                           Computer Science Journals
# 7                                         Eko Journal
# 8              European Journals of Education Studies
# 9   International Conference on Computer Science a...
# 10              International Skill Research Journals
# 11                                 IORE International
# 12                                    Medical science
# 13                                       Net Journals
# 14                                           Newpubli
# 15                               Open Journal Systems
# 16                                  ORIC Publications
# 17                                       PBS Journals
# 18                                Revistas Academicas
# 19                                SAVAP International
# 20                                      Science Alert
# 21                  Science and Technology Publishing
# 22                  Scientific Journals International
# 23                                            SCITECH
# 24                                           Scitechz
# 25                                    SS Publications
# 26                                        TI Journals
# 27                             USN Scientific Journal
# 28                        VSRD International Journals
# 29                                     World Scholars

# %% [markdown]
#     Now we can see that some of them are same, some we are not sure, some are different.
#     Let's also save the results into a CSV file.

# %%
comparison.to_csv('compared_results.csv', index=False)

# %% [markdown]
# ## Show the results in table with links
#     As we found that there are some journals we are not sure if they are same in the previous part, now let's check to make the dicision.
#
#     First, let's get to the webpage https://beallslist.weebly.com/ which we get the Beall's list.
#     Find the journals we are not sure by name to get into the journals official website.
#     Then also use the TroveURL get from the list from Trove, to have a look of the Trove page of the journal.
#     Now, we know which of them are the same ones. Put their information in to a CSV file, and load it into dataframe to see the results.

# %%
pd.set_option('max_colwidth',100)
#read journals from csv file
results = pd.read_csv("./results.csv", sep = ',')
results
# Out:
#                                     Title  \
# 0       Scientific Journals International
# 1               Computer Science Journals
# 2                         Medical science
# 3                                Newpubli
# 4       Science and Technology Publishing
# 5                           Science Alert
# 6                    Open Journal Systems
# 7              American Research Journals
# 8  European Journals of Education Studies
#
#                                                     Link
# 0                     http://www.scientificjournals.org/
# 1                            http://www.cscjournals.org/
# 2            http://www.ghrnet.org/index.php/index/index
# 3                    http://www.newpubli.com/index.shtml
# 4                              http://www.scitecpub.com/
# 5                                  https://scialert.net/
# 6  http://ambs-journal.co.uk/ojs-2.4.7-1/index.php/index
# 7                             https://www.arjonline.org/
# 8                  https://oapub.org/edu/index.php/index

# %% [markdown]
#     Here it is! With the title and links for researchers to see clearly.
